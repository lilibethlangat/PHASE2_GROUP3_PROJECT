# %%
# Checking my working directory
import os
os.getcwd()
# Out:
# 'c:\\Users\\User\\PHASE2_GROUP3_PROJECT'

# %%
# check on files within the directorate
os.listdir()
# Out:
# ['.git',
#  '.gitattributes',
#  '.gitignore',
#  'Data',
#  'movies.ipynb',
#  'README.md',
#  'Untitled-2.ipynb']

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\User\PHASE2_GROUP3_PROJECT

# %%
# Files in the data folder
print(os.listdir('data'))
# Out:
# ['bom.movie_gross.csv', 'rt.movie_info.tsv', 'rt.reviews.tsv', 'tmdb.movies.csv', 'tn.movie_budgets.csv']

# %%
import pandas as pd
bom_df = pd.read_csv('data/bom.movie_gross.csv')
rtm_df = pd.read_csv('data/rt.movie_info.tsv', sep='\t')
rtr_df = pd.read_csv('data/rt.reviews.tsv', sep='\t', encoding='latin1')
tmdb_df = pd.read_csv('data/tmdb.movies.csv')
tn_df = pd.read_csv('data/tn.movie_budgets.csv')

# %%
bom_df.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
rtm_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
rtr_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
tmdb_df.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# ...

# %%
tn_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# # Column types and missing values

# %%
bom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
rtm_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
rtr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26517 entries, 0 to 26516
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         26517 non-null  int64
#  1   genre_ids          26517 non-null  object
#  2   id                 26517 non-null  int64
#  3   original_language  26517 non-null  object
#  4   original_title     26517 non-null  object
#  5   popularity         26517 non-null  float64
#  6   release_date       26517 non-null  object
#  7   title              26517 non-null  object
#  8   vote_average       26517 non-null  float64
#  9   vote_count         26517 non-null  int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 2.0+ MB

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# Defining Columns - listing all column names

# %%
bom_df.columns
# Out:
# Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year'], dtype='object')

# %%
rtm_df.columns
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')

# %%
rtr_df.columns
# Out:
# Index(['id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher',
#        'date'],
#       dtype='object')

# %%
tmdb_df.columns
# Out:
# Index(['Unnamed: 0', 'genre_ids', 'id', 'original_language', 'original_title',
#        'popularity', 'release_date', 'title', 'vote_average', 'vote_count'],
#       dtype='object')

# %%
tn_df.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross'],
#       dtype='object')

# %% [markdown]
# Summary stats for numeric columns

# %%
bom_df.describe()
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
rtm_df.describe()
# Out:
#                 id
# count  1560.000000
# mean   1007.303846
# std     579.164527
# min       1.000000
# 25%     504.750000
# 50%    1007.500000
# 75%    1503.250000
# max    2000.000000

# %%
rtr_df.describe()
# Out:
#                  id    top_critic
# count  54432.000000  54432.000000
# mean    1045.706882      0.240594
# std      586.657046      0.427448
# min        3.000000      0.000000
# 25%      542.000000      0.000000
# 50%     1083.000000      0.000000
# 75%     1541.000000      0.000000
# max     2000.000000      1.000000

# %%
tmdb_df.describe()
# Out:
#         Unnamed: 0             id    popularity  vote_average    vote_count
# count  26517.00000   26517.000000  26517.000000  26517.000000  26517.000000
# mean   13258.00000  295050.153260      3.130912      5.991281    194.224837
# std     7654.94288  153661.615648      4.355229      1.852946    960.961095
# min        0.00000      27.000000      0.600000      0.000000      1.000000
# 25%     6629.00000  157851.000000      0.600000      5.000000      2.000000
# 50%    13258.00000  309581.000000      1.374000      6.000000      5.000000
# 75%    19887.00000  419542.000000      3.694000      7.000000     28.000000
# max    26516.00000  608444.000000     80.773000     10.000000  22186.000000

# %%
tn_df.describe()
# Out:
#                 id
# count  5782.000000
# mean     50.372363
# std      28.821076
# min       1.000000
# 25%      25.000000
# 50%      50.000000
# 75%      75.000000
# max     100.000000

# %%
# standardizing columns
bom_df.columns = bom_df.columns.str.strip().str.lower().str.replace(' ', '_')
rtm_df.columns = rtm_df.columns.str.strip().str.lower().str.replace(' ', '_')
rtr_df.columns = rtr_df.columns.str.strip().str.lower().str.replace(' ', '_')
tmdb_df.columns = tmdb_df.columns.str.strip().str.lower().str.replace(' ', '_')
tn_df.columns = tn_df.columns.str.strip().str.lower().str.replace(' ', '_')

# %% [markdown]
# # Handling missing values
# ## Counting missing values

# %%
bom_df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
rtm_df.isnull().sum()
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %%
rtr_df.isnull().sum()
# Out:
# id                0
# review         5563
# rating        13517
# fresh             0
# critic         2722
# top_critic        0
# publisher       309
# date              0
# dtype: int64

# %% [markdown]
# # Drop rows missing critical information
# bom_df.isnull().sum()

# %%
# since our analysis depends heavily on revenue generated
bom_df_cleaned = bom_df.dropna(subset=['domestic_gross', 'foreign_gross'])

# %%
# studio data is not that critical, we can replace the missing values
bom_df_cleaned['studio'] = bom_df_cleaned['studio'].fillna('Unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2504\1369580956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bom_df_cleaned['studio'] = bom_df_cleaned['studio'].fillna('Unknown')

# %% [markdown]
# For dataset

# %%
# Currency and box_office are very essential in our analysis, we have to drop missing rows
rtm_df_cleaned = rtm_df.dropna(subset=['box_office', 'currency', 'rating', 'director', 'writer', 'runtime'])

# %% [markdown]
# # the other metadata are optional, hence can be filled

# %%
optional_cols = ['studio']
rtm_df_cleaned[optional_cols] = rtm_df_cleaned[optional_cols].fillna('Unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2504\3731214530.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rtm_df_cleaned[optional_cols] = rtm_df_cleaned[optional_cols].fillna('Unknown')

# %% [markdown]
# # Convert dates and handle missing ones
# Converting dates is useful in trend analysis.

# %%
rtm_df_cleaned['theater_date'] = pd.to_datetime(rtm_df_cleaned['theater_date'], errors='coerce')
rtm_df_cleaned['dvd_date'] = pd.to_datetime(rtm_df_cleaned['dvd_date'], errors='coerce')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2504\1649059310.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rtm_df_cleaned['theater_date'] = pd.to_datetime(rtm_df_cleaned['theater_date'], errors='coerce')
# C:\Users\User\AppData\Local\Temp\ipykernel_2504\1649059310.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rtm_df_cleaned['dvd_date'] = pd.to_datetime(rtm_df_cleaned['dvd_date'], errors='coerce')

# %% [markdown]
# # Dataset

# %%
# drop critical missing rows
rtr_df_cleaned = rtr_df.dropna(subset=['rating'])

# %%
# non critical
rtr_df_cleaned[['review', 'critic', 'publisher']] = rtr_df_cleaned[['review', 'critic', 'publisher']].fillna('Unknown')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2504\2018776521.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rtr_df_cleaned[['review', 'critic', 'publisher']] = rtr_df_cleaned[['review', 'critic', 'publisher']].fillna('Unknown')

# %%
# Convert date to datetime
rtr_df_cleaned['date'] = pd.to_datetime(rtr_df_cleaned['date'], errors='coerce')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2504\4041576152.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rtr_df_cleaned['date'] = pd.to_datetime(rtr_df_cleaned['date'], errors='coerce')

# %%
# Extract year or month for trend analysis
rtr_df_cleaned['year'] = rtr_df_cleaned['date'].dt.year
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2504\4265553896.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rtr_df_cleaned['year'] = rtr_df_cleaned['date'].dt.year

# %%
# Remove duplicates
df.drop_duplicates(subset=['title', 'release_year'], inplace=True)

# %%
# clean text columns
bom_df['title'] = bom_df['title'].str.strip().str.lower()
rtm_df['genre'] = rtm_df['genre'].str.strip().str.lower()
tmdb_df['title'] = tmdb_df['title'].str.strip().str.lower()

# %%
# convert data types
rtm_df['runtime'] = pd.to_numeric(rtm_df['runtime'], errors='coerce')
tmdb_df['release_date'] = pd.to_numeric(tmdb_df['release_date'], errors='coerce')

# %% [markdown]
# # Save cleaned data

# %%
bom_df.to_csv('cleaned_bom.movie_gross.csv')
rtm_df.to_csv('cleaned_rt.movie_info.tsv', sep='\t')
rtr_df.to_csv('cleaned_rt.reviews.tsv', sep='\t', encoding='latin1')
tmdb_df.to_csv('cleaned_tmdb.movies.csv')
tn_df .to_csv('cleaned_tn.movie_budgets.csv')

# %% [markdown]
# # Merge the cleaned datasets
# start by importing the cleaned datasets

# %%
import pandas as pd
bom_df = pd.read_csv('cleaned_bom.movie_gross.csv')
rtm_df = pd.read_csv('cleaned_rt.movie_info.tsv', sep='\t')
rtr_df = pd.read_csv('cleaned_rt.reviews.tsv', sep='\t', encoding='latin1')
tmdb_df = pd.read_csv('cleaned_tmdb.movies.csv')
tn_df  = pd.read_csv('cleaned_tn.movie_budgets.csv')

# %% [markdown]
# # Choose a Common Merge Key
# From the datasets, the most common ones are; title and release_date. Normalize them across all datasets:

# %%
for df in [bom_df, rtm_df, rtr_df, tmdb_df, tn_df]:
    if 'title' in df.columns:
        df['title'] = df['title'].str.strip().str.lower()
    if 'release date' in df.columns:
        df['release date'] = pd.to_numeric(df['release date'], errors='coerce')

# %% [markdown]
# # Log missing columns
# This helps keep track of which DataFrames are missing expected columns

# %%
for name, df in zip(['bom_df', 'rtm_df', 'rtr_df', 'tmdb_df', 'tn_df'], [bom_df, rtm_df, rtr_df, tmdb_df, tn_df]):
    if 'title' in df.columns:
        df['title'] = df['title'].str.strip().str.lower()
    else:
        print(f"⚠️ 'title' column missing in {name}")
    if 'release date' in df.columns:
        df['release date'] = pd.to_numeric(df['release date'], errors='coerce')
    else:
        print(f"⚠️ 'release date' column missing in {name}")
# Out:
# ⚠️ 'release date' column missing in bom_df
# ⚠️ 'title' column missing in rtm_df
# ⚠️ 'release date' column missing in rtm_df
# ⚠️ 'title' column missing in rtr_df
# ⚠️ 'release date' column missing in rtr_df
# ⚠️ 'release date' column missing in tmdb_df
# ⚠️ 'title' column missing in tn_df
# ⚠️ 'release date' column missing in tn_df

# %%
# summary of each DataFrame’s columns
for name, df in zip(['bom_df', 'rtm_df', 'rtr_df', 'tn_df', 'tmdb_df'], [bom_df, rtm_df, rtr_df, tn_df, tmdb_df]):
    print(f"{name}: {df.columns.tolist()}")
# Out:
# bom_df: ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year']
# rtm_df: ['Unnamed: 0', 'id', 'synopsis', 'rating', 'genre', 'director', 'writer', 'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime', 'studio']
# rtr_df: ['Unnamed: 0', 'id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher', 'date']
# tn_df: ['Unnamed: 0', 'id', 'release_date', 'movie', 'production_budget', 'domestic_gross', 'worldwide_gross']
# tmdb_df: ['Unnamed: 0', 'unnamed:_0', 'genre_ids', 'id', 'original_language', 'original_title', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']

# %%
# normalize titles, dates, and IDs across datasets
df['title'] = df['title'].str.strip().str.lower()

# %%
# merge dataset (decide on a primary key—likely 'title' and 'release date')
merged_df = pd.merge(bom_df, tmdb_df, on='title', how='inner')

# %% [markdown]
# # Exploratory Data Analysis (EDA)
# Look at distributions, missing values, and outliers:

# %%
merged_df.describe()
merged_df.isnull().sum()
# Out:
# title                   0
# studio                  1
# domestic_gross         21
# foreign_gross        1013
# year                    0
# Unnamed: 0              0
# unnamed:_0              0
# genre_ids               0
# id                      0
# original_language       0
# original_title          0
# popularity              0
# release_date         2790
# vote_average            0
# vote_count              0
# dtype: int64

# %% [markdown]
# # Cleaning and preparing the movie dataset

# %%
def clean_movie_data(df, title_col='title', year_col='release year'):
    if title_col not in df.columns or year_col not in df.columns:
        print(f"Missing expected columns: {title_col}, {year_col}")
        return df
    print("Cleaning started...")

# %%
# Standardize column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# Rename title/date columns if needed
title_col = 'movie_title'
year_col = 'year_date'

if title_col != 'title':
        df.rename(columns={title_col: 'title'}, inplace=True)
if year_col != 'year_date':
        df.rename(columns={date_col: 'year_date'}, inplace=True)

# %%
# Clean text columns
def clean_movie_data(df):
    df["title"] = df["title"].astype(str).str.strip().str.lower()
    df["release_date"] = pd.to_numeric(df["release_date"], errors='coerce')
    return df

# %%
# Create merge key
def clean_movie_data(df):
    df["title"] = df["title"].astype(str).str.strip().str.lower()
    df["release_date"] = pd.to_numeric(df["release_date"], errors='coerce')
    df["merge_key"] = df["title"] + "_" + df["release_date"].astype(str)
    return df

# %%
# Drop unnecessary columns
def clean_movie_data(df, drop_cols=None):
    if drop_cols:
        df.drop(columns=drop_cols, inplace=True, errors='ignore')
    return df

# %%
# Handle missing values
def clean_movie_data(df, drop_cols=None):
    df.dropna(subset=['title', 'release_date'], inplace=True)
    df.fillna({'studio': 'unknown', 'domestic_gross': 0, 'foreign_gross': 0}, inplace=True)

# %%
def clean_movie_data(df, title_col='title', year_col='release_year'):
    if title_col not in df.columns or year_col not in df.columns:
        print(f"Missing expected columns: {title_col}, {year_col}")
        return df
    # Continue cleaning...
    if title_col not in df.columns or year_col not in df.columns:
        print(f"Missing expected columns: {title_col}, {year_col}")
        return df  # ← this should return the original DataFrame, not None
    
def clean_movie_data(df, title_col='title', year_col='year'):
    # Check if expected columns exist
    if title_col not in df.columns or year_col not in df.columns:
        print(f"Missing expected columns: {title_col}, {year_col}")
        return df  # ✅ This ensures it returns the original DataFrame, not None

def clean_movie_data(df, title_col='title', year_col='year'):
    print("Function entered")
    if title_col not in df.columns or year_col not in df.columns:
        print(f"Missing expected columns: {title_col}, {year_col}")
        return df

    print("Cleaning started...")
    df[title_col] = df[title_col].astype(str).str.strip().str.lower()
    df[year_col] = pd.to_numeric(df[year_col], errors='coerce')
    df['merge_key'] = df[title_col] + '_' + df[year_col].astype(str)

    print("Cleaning complete")
    return df

# %%
cleaned_bom = clean_movie_data(bom_df, title_col='title', year_col='year')
# Out:
# Function entered
# Cleaning started...
# Cleaning complete

# %%
print(bom_df.columns.tolist())
# Out:
# ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year', 'merge_key']

# %%
cleaned_bom = clean_movie_data(bom_df, title_col='title', year_col='year')
# Out:
# Function entered
# Cleaning started...
# Cleaning complete

# %%
print(type(cleaned_rt))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
 Clean title column
    df[title_col] = df[title_col].astype(str).str.strip().str.lower()

    # Clean year column
    df[year_col] = pd.to_numeric(df[year_col], errors='coerce')
# Out:
#   Cell In[279], line 1
#     Clean title column
#           ^
# SyntaxError: invalid syntax

# %%
print(bom_df.columns.tolist())
# Out:
# ['title', 'studio', 'domestic_gross', 'foreign_gross', 'year']

# %%
cleaned_bom = clean_movie_data(bom_df, title_col='title', year_col='year')  # adjust as needed

# %%
master_df = cleaned_bom.merge(cleaned_rt, on='merge_key', how='inner')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[258], line 1
# ----> 1 master_df = cleaned_bom.merge(cleaned_rt, on='merge_key', how='inner')
#
# AttributeError: 'NoneType' object has no attribute 'merge'

# %%
# applying the cleaning function
bom_df = pd.read_csv('data/bom.movie_gross.csv')
rtm_df = pd.read_csv('data/rt.movie_info.tsv', sep='\t')
rtr_df = pd.read_csv('data/rt.reviews.tsv', sep='\t', encoding='latin1')

cleaned_bom = clean_movie_data(bom_df)
cleaned_rtm = clean_movie_data(rtm_df)
cleaned_rtr = clean_movie_data(rtr_df)
# Out:
# Missing expected columns: title, release_year
# Missing expected columns: title, release_year
# Missing expected columns: title, release_year

# %%
cleaned_bom = clean_movie_data(bom_df, title_col='title', year_col='year')
cleaned_rtm = clean_movie_data(rtm_df, title_col='movie', year_col='year')
cleaned_rtr = clean_movie_data(rtr_df, title_col='movie', year_col='release_year')
# Out:
# Missing expected columns: movie, year
# Missing expected columns: movie, release_year

# %%
cleaned_bom = clean_movie_data(bom_df, title_col='title', year_col='year')  # if those exist
cleaned_rtm = clean_movie_data(rtm_df, title_col='name', year_col='release_date')  # adjust as needed
cleaned_rtr = clean_movie_data(rtr_df, title_col='movie_title', year_col='release_year')  # adjust as needed
# Out:
# Missing expected columns: name, release_date
# Missing expected columns: movie_title, release_year

# %%
cleaned_rt = clean_movie_data(rtm_df, title_col='actual_title_column', year_col='actual_year_column')
# Out:
# Missing expected columns: actual_title_column, actual_year_column

# %%
cleaned_rt = clean_movie_data(rtr_df, title_col='movie_title', year_col='release_year')
# Out:
# Missing expected columns: movie_title, release_year

# %%
print(rtr_df.columns.tolist())
# Out:
# ['id', 'review', 'rating', 'fresh', 'critic', 'top_critic', 'publisher', 'date']

# %%
cleaned_rt = clean_movie_data(rtr_df, title_col='title', year_col='release_date')
# Out:
# Missing expected columns: title, release_date

# %%
df['release_year'] = pd.to_datetime(df['release_date'], errors='coerce').dt.year

# %%
# combining rtr and rtm
rt_combined = rtr_df.merge(rtm_df, on='id', how='left')

# %%
print(rt_combined.columns.tolist())
# Out:
# ['id', 'review', 'rating_x', 'fresh', 'critic', 'top_critic', 'publisher', 'date', 'synopsis', 'rating_y', 'genre', 'director', 'writer', 'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime', 'studio']

# %%
cleaned_rt = clean_movie_data(rt_combined, title_col='movie', year_col='year')  # adjust based on actual column names
cleaned_rt = clean_movie_data(rt_combined, title_col='movie', year_col='year')  # adjust based on actual column names
# Out:
# Function entered
# Missing expected columns: movie, year
# Function entered
# Missing expected columns: movie, year

# %%
print(rt_combined.columns.tolist())
# Out:
# ['id', 'review', 'rating_x', 'fresh', 'critic', 'top_critic', 'publisher', 'date', 'synopsis', 'rating_y', 'genre', 'director', 'writer', 'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime', 'studio']

# %%
rt_full = rt_combined.merge(rtm_df, on='id', how='left')

# %%
print(rt_full.columns.tolist())
# Out:
# ['id', 'review', 'rating_x', 'fresh', 'critic', 'top_critic', 'publisher', 'date', 'synopsis_x', 'rating_y', 'genre_x', 'director_x', 'writer_x', 'theater_date_x', 'dvd_date_x', 'currency_x', 'box_office_x', 'runtime_x', 'studio_x', 'synopsis_y', 'rating', 'genre_y', 'director_y', 'writer_y', 'theater_date_y', 'dvd_date_y', 'currency_y', 'box_office_y', 'runtime_y', 'studio_y']

# %%
cleaned_rt = clean_movie_data(rt_full, title_col='synopsis_x', year_col='year')  # adjust title_col if needed
# Out:
# Function entered
# Missing expected columns: synopsis_x, year

# %%
print(rt_full.columns.tolist())
# Out:
# ['id', 'review', 'rating_x', 'fresh', 'critic', 'top_critic', 'publisher', 'date', 'synopsis_x', 'rating_y', 'genre_x', 'director_x', 'writer_x', 'theater_date_x', 'dvd_date_x', 'currency_x', 'box_office_x', 'runtime_x', 'studio_x', 'synopsis_y', 'rating', 'genre_y', 'director_y', 'writer_y', 'theater_date_y', 'dvd_date_y', 'currency_y', 'box_office_y', 'runtime_y', 'studio_y']

# %%
rt_full['year'] = pd.to_datetime(rt_full['date'], errors='coerce').dt.year

# %%
rt_full = rt_combined.merge(rtm_df, on='id', how='left')

# %%
print(rt_full.columns.tolist())
# Out:
# ['id', 'review', 'rating_x', 'fresh', 'critic', 'top_critic', 'publisher', 'date', 'synopsis_x', 'rating_y', 'genre_x', 'director_x', 'writer_x', 'theater_date_x', 'dvd_date_x', 'currency_x', 'box_office_x', 'runtime_x', 'studio_x', 'synopsis_y', 'rating', 'genre_y', 'director_y', 'writer_y', 'theater_date_y', 'dvd_date_y', 'currency_y', 'box_office_y', 'runtime_y', 'studio_y']

# %%
rt_full['synopsis_y']  # ← This is probably the movie title or description
# Out:
# 0        New York City, not-too-distant-future: Eric Pa...
# 1        New York City, not-too-distant-future: Eric Pa...
# 2        New York City, not-too-distant-future: Eric Pa...
# 3        New York City, not-too-distant-future: Eric Pa...
# 4        New York City, not-too-distant-future: Eric Pa...
#                                ...
# 54427    Suspended from the force, Paris cop Hubert is ...
# 54428    Suspended from the force, Paris cop Hubert is ...
# 54429    Suspended from the force, Paris cop Hubert is ...
# 54430    Suspended from the force, Paris cop Hubert is ...
# 54431    Suspended from the force, Paris cop Hubert is ...
# Name: synopsis_y, Length: 54432, dtype: object

# %%
print(rt_full[['studio_y']].dropna().head(10))
# Out:
#             studio_y
# 0  Entertainment One
# 1  Entertainment One
# 2  Entertainment One
# 3  Entertainment One
# 4  Entertainment One
# 5  Entertainment One
# 6  Entertainment One
# 7  Entertainment One
# 8  Entertainment One
# 9  Entertainment One

# %%
print(rt_full[['synopsis_y']].dropna().head(10))
# Out:
#                                           synopsis_y
# 0  New York City, not-too-distant-future: Eric Pa...
# 1  New York City, not-too-distant-future: Eric Pa...
# 2  New York City, not-too-distant-future: Eric Pa...
# 3  New York City, not-too-distant-future: Eric Pa...
# 4  New York City, not-too-distant-future: Eric Pa...
# 5  New York City, not-too-distant-future: Eric Pa...
# 6  New York City, not-too-distant-future: Eric Pa...
# 7  New York City, not-too-distant-future: Eric Pa...
# 8  New York City, not-too-distant-future: Eric Pa...
# 9  New York City, not-too-distant-future: Eric Pa...

# %%
rt_full['year'] = pd.to_datetime(rt_full['date'], errors='coerce').dt.year

# %%
cleaned_rt = clean_movie_data(rt_full, title_col='synopsis_y', year_col='year')
print('merge_key' in cleaned_rt.columns)
# Out:
# Function entered
# Cleaning started...
# Cleaning complete
# True

# %%
cleaned_bom = clean_movie_data(bom_df, title_col='title', year_col='year')
print('merge_key' in cleaned_bom.columns)
# Out:
# Function entered
# Cleaning started...
# Cleaning complete
# True

# %%
print(type(cleaned_rt))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
master_df = cleaned_bom.merge(cleaned_rt, on='merge_key', how='inner')
print(master_df.shape)
master_df.head()
# Out:
# (0, 37)
# Empty DataFrame
# Columns: [title, studio, domestic_gross, foreign_gross, year_x, merge_key, id, review, rating_x, fresh, critic, top_critic, publisher, date, synopsis_x, rating_y, genre_x, director_x, writer_x, theater_date_x, dvd_date_x, currency_x, box_office_x, runtime_x, studio_x, synopsis_y, rating, genre_y, director_y, writer_y, theater_date_y, dvd_date_y, currency_y, box_office_y, runtime_y, studio_y, year_y]
# Index: []
#
# [0 rows x 37 columns]

# %%
print(cleaned_bom['merge_key'].dropna().head(10))
print(cleaned_rt['merge_key'].dropna().head(10))
# Out:
# 0                                    toy story 3_2010
# 1                     alice in wonderland (2010)_2010
# 2    harry potter and the deathly hallows part 1_2010
# 3                                      inception_2010
# 4                            shrek forever after_2010
# 5                     the twilight saga: eclipse_2010
# 6                                     iron man 2_2010
# 7                                        tangled_2010
# 8                                  despicable me_2010
# 9                       how to train your dragon_2010
# Name: merge_key, dtype: object
# 0    new york city, not-too-distant-future: eric pa...
# 1    new york city, not-too-distant-future: eric pa...
# 2    new york city, not-too-distant-future: eric pa...
# 3    new york city, not-too-distant-future: eric pa...
# 4    new york city, not-too-distant-future: eric pa...
# 5    new york city, not-too-distant-future: eric pa...
# 6    new york city, not-too-distant-future: eric pa...
# ...

# %%
print(cleaned_bom['title'].dropna().head(10))
print(cleaned_rt['synopsis_y'].dropna().head(10))  # or whatever column you used as title_col
# Out:
# 0                                    toy story 3
# 1                     alice in wonderland (2010)
# 2    harry potter and the deathly hallows part 1
# 3                                      inception
# 4                            shrek forever after
# 5                     the twilight saga: eclipse
# 6                                     iron man 2
# 7                                        tangled
# 8                                  despicable me
# 9                       how to train your dragon
# Name: title, dtype: object
# 0    new york city, not-too-distant-future: eric pa...
# 1    new york city, not-too-distant-future: eric pa...
# 2    new york city, not-too-distant-future: eric pa...
# 3    new york city, not-too-distant-future: eric pa...
# 4    new york city, not-too-distant-future: eric pa...
# 5    new york city, not-too-distant-future: eric pa...
# 6    new york city, not-too-distant-future: eric pa...
# 7    new york city, not-too-distant-future: eric pa...
# ...

# %%
print(rtm_df.columns.tolist())
# Out:
# ['id', 'synopsis', 'rating', 'genre', 'director', 'writer', 'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime', 'studio']

# %%
rt_full = rt_combined.merge(rtm_df, on='id', how='left')

# %%
rt_full['year'] = pd.to_datetime(rt_full['theater_date_y'], errors='coerce').dt.year

# %%
# extracting year from theater
cleaned_rt = clean_movie_data(rt_full, title_col='synopsis_y', year_col='year')  # or use 'studio_y' if 'synopsis_y' isn't a title
# Out:
# Function entered
# Cleaning started...
# Cleaning complete

# %%
master_df = cleaned_bom.merge(cleaned_rt, on='merge_key', how='inner')
print(master_df.shape)
# Out:
# (0, 37)

# %%
# checking on the formats
print("cleaned_bom keys:")
print(cleaned_bom['merge_key'].dropna().str.lower().str.strip().unique()[:10])

print("\ncleaned_rt keys:")
print(cleaned_rt['merge_key'].dropna().str.lower().str.strip().unique()[:10])
# Out:
# cleaned_bom keys:
# ['toy story 3_2010' 'alice in wonderland (2010)_2010'
#  'harry potter and the deathly hallows part 1_2010' 'inception_2010'
#  'shrek forever after_2010' 'the twilight saga: eclipse_2010'
#  'iron man 2_2010' 'tangled_2010' 'despicable me_2010'
#  'how to train your dragon_2010']
#
# cleaned_rt keys:
# ...

# %% [markdown]
# Your cleaned_rt merge keys are built from plot summaries, not movie titles. That’s why none of them match the cleaned_bom keys like "toy story 3_2010" or "inception_2010".

# %%
# Use a Real Title Column
rtm_df['studio']  # ← not ideal, but it's the closest i've got
# Out:
# 0                     NaN
# 1       Entertainment One
# 2                     NaN
# 3                     NaN
# 4                     NaN
#               ...
# 1555      New Line Cinema
# 1556    Paramount Vantage
# 1557                  NaN
# 1558                  NaN
# 1559    Columbia Pictures
# Name: studio, Length: 1560, dtype: object

# %%
rt_full = rt_combined.merge(rtm_df, on='id', how='left')
rt_full['year'] = pd.to_datetime(rt_full['theater_date_y'], errors='coerce').dt.year

# %%
cleaned_rt = clean_movie_data(rt_full, title_col='studio_y', year_col='year')
# Out:
# Function entered
# Cleaning started...
# Cleaning complete

# %%
print(rtm_df[['studio', 'synopsis']].dropna().head(10))
# Out:
#                         studio  \
# 1            Entertainment One
# 5        Warner Bros. Pictures
# 6           Paramount Pictures
# 7       Sony Pictures Classics
# 11  Showtime Documentary Films
# 12       Seventh Art Releasing
# 15                ATO Pictures
# 16               Sony Pictures
# 18          Universal Pictures
# 19                         MGM
#
#                                              synopsis
# 1   New York City, not-too-distant-future: Eric Pa...
# 5   The year is 1942. As the Allies unite overseas...
# 6   Some cast and crew from NBC's highly acclaimed...
# 7   Stewart Kane, an Irishman living in the Austra...
# 11  In 1979, Bill Viola and Frank Caliguri dreamed...
# 12  While Microsoft may be the biggest software co...
# 15  Two-time Academy Award Winner Kevin Spacey giv...
# 16  A fictional film set in the alluring world of ...
# 18  From ancient Japan's most enduring tale, the e...
# 19  A comic series of short vignettes build on one...

# %% [markdown]
#  'studio' and 'synopsis' in rtm_df are not usable as movie titles. 'studio' gives you production companies like Warner Bros. or Sony Pictures, and 'synopsis' gives you long plot summaries. Neither matches the 'title' column in bom_df, which contains clean movie names like "Toy Story 3" or "Inception".

# %%
# using studio as a proxy

# %%
cleaned_rt = clean_movie_data(rt_full, title_col='studio_y', year_col='year')
# Out:
# Function entered
# Cleaning started...
# Cleaning complete

# %%
master_df = cleaned_bom.merge(cleaned_rt, on='merge_key', how='inner')
print(master_df.shape)
# Out:
# (0, 37)

# %% [markdown]
# # Let us try a different column

# %%
print(rtm_df.columns)
rtm_df.head(3)
# Out:
# Index(['id', 'synopsis', 'rating', 'genre', 'director', 'writer',
#        'theater_date', 'dvd_date', 'currency', 'box_office', 'runtime',
#        'studio'],
#       dtype='object')
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
#
# ...

# %%
print(rt_combined.columns)
rt_combined.head(3)
# Out:
# Index(['id', 'review', 'rating_x', 'fresh', 'critic', 'top_critic',
#        'publisher', 'date', 'synopsis', 'rating_y', 'genre', 'director',
#        'writer', 'theater_date', 'dvd_date', 'currency', 'box_office',
#        'runtime', 'studio'],
#       dtype='object')
#    id                                             review rating_x   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...      3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...      NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...      NaN   fresh
#
#            critic  top_critic         publisher               date  \
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
#
#                                             synopsis rating_y  \
# 0  New York City, not-too-distant-future: Eric Pa...        R
# ...

# %%
print(rt_combined['review'].dropna().head(10))
# Out:
# 0    A distinctly gallows take on contemporary fina...
# 1    It's an allegory in search of a meaning that n...
# 2    ... life lived in a bubble in financial dealin...
# 3    Continuing along a line introduced in last yea...
# 4               ... a perverse twist on neorealism...
# 5    ... Cronenberg's Cosmopolis expresses somethin...
# 6    Quickly grows repetitive and tiresome, meander...
# 7    Cronenberg is not a director to be daunted by ...
# 8    Cronenberg's cold, exacting precision and emot...
# 9    Over and above its topical urgency or the bit ...
# Name: review, dtype: object

# %% [markdown]
# # Merging Box Office Mojo (BOM) dataset with The Movie Database (TMDb) and The Numbers (TN)

# %%
# Standardize Titles and Years
def create_merge_key(df, title_col, year_col):
    return df[title_col].str.lower().str.strip() + '_' + df[year_col].astype(str)

# %%
print("bom_df columns:", bom_df.columns)
print("tmdb_df columns:", tmdb_df.columns)
print("tn_df columns:", tn_df.columns)
# Out:
# bom_df columns: Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year',
#        'merge_key'],
#       dtype='object')
# tmdb_df columns: Index(['unnamed:_0', 'unnamed:_0', 'genre_ids', 'id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'title', 'vote_average',
#        'vote_count', 'release_year'],
#       dtype='object')
# tn_df columns: Index(['Unnamed: 0', 'id', 'release_date', 'movie', 'production_budget',
#        'domestic_gross', 'worldwide_gross'],
#       dtype='object')

# %%
# for tmdb we already have 'release_year'

tmdb_df['year'] = tmdb_df['release_year']

# %%
# For tn.df Extract year from 'release_date':
tn_df['year'] = pd.to_datetime(tn_df['release_date'], errors='coerce').dt.year

# %%
# apply merge_key to all
def create_merge_key(df, title_col, year_col):
    return df[title_col].str.lower().str.strip() + '_' + df[year_col].astype(str)

bom_df['merge_key'] = create_merge_key(bom_df, 'title', 'year')
tmdb_df['merge_key'] = create_merge_key(tmdb_df, 'title', 'year')
tn_df['merge_key'] = create_merge_key(tn_df, 'movie', 'year')

# %%
merged_df = bom_df.merge(tmdb_df, on='merge_key', how='left')
merged_df = merged_df.merge(tn_df, on='merge_key', how='left')
print(merged_df.shape)
merged_df.head()
# Out:
# (3387, 27)
#                                        title_x studio  domestic_gross_x  \
# 0                                  toy story 3     BV       415000000.0
# 1                   alice in wonderland (2010)     BV       334200000.0
# 2  harry potter and the deathly hallows part 1     WB       296000000.0
# 3                                    inception     WB       292600000.0
# 4                          shrek forever after   P/DW       238700000.0
#
#   foreign_gross  year_x                                         merge_key  \
# 0     652000000    2010                                  toy story 3_2010
# 1     691300000    2010                   alice in wonderland (2010)_2010
# 2     664300000    2010  harry potter and the deathly hallows part 1_2010
# 3     535700000    2010                                    inception_2010
# 4     513900000    2010                          shrek forever after_2010
#
#    unnamed:_0  unnamed:_0 genre_ids  id_x  ... release_year year_y  \
# ...

# %% [markdown]
# # With the above merged data,let us start off to:
# ## analyze which directors and writers consistently produce successful movies

# %%
print(merged_df.columns)
# Out:
# Index(['title_x', 'studio', 'domestic_gross_x', 'foreign_gross', 'year_x',
#        'merge_key', 'unnamed:_0', 'unnamed:_0', 'genre_ids', 'id_x',
#        'original_language', 'original_title', 'popularity', 'release_date_x',
#        'title_y', 'vote_average', 'vote_count', 'release_year', 'year_y',
#        'Unnamed: 0', 'id_y', 'release_date_y', 'movie', 'production_budget',
#        'domestic_gross_y', 'worldwide_gross', 'year'],
#       dtype='object')

# %%
merged_df['total_gross'] = (
    merged_df['worldwide_gross'].fillna(0) +
    merged_df['domestic_gross'].fillna(0) +
    merged_df['foreign_gross'].fillna(0)
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\.anaconda\conda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File pandas/_libs/index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File pandas/_libs/index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'domestic_gross'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# create total gross column
merged_df['total_gross'] = merged_df['worldwide_gross'].fillna(0) + merged_df['domestic_gross'].fillna(0) + merged_df['foreign_gross'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\User\.anaconda\conda3\envs\learn-env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:191, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:234, in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# File pandas/_libs/index.pyx:242, in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# File pandas/_libs/index.pyx:134, in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: 'domestic_gross'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print("bom_df columns:", bom_df.columns)
print("tmdb_df columns:", tmdb_df.columns)
print("tn_df columns:", tn_df.columns)
# Out:
# bom_df columns: Index(['title', 'studio', 'domestic_gross', 'foreign_gross', 'year',
#        'merge_key'],
#       dtype='object')
# tmdb_df columns: Index(['unnamed:_0', 'unnamed:_0', 'genre_ids', 'id', 'original_language',
#        'original_title', 'popularity', 'release_date', 'title', 'vote_average',
#        'vote_count', 'release_year'],
#       dtype='object')
# tn_df columns: Index(['Unnamed: 0', 'id', 'release_date', 'movie', 'production_budget',
#        'domestic_gross', 'worldwide_gross'],
#       dtype='object')

# %% [markdown]
# Objective 1: Which Genres Have the Highest Ratings and Generate the Most Revenue?
# using bom and IMDB data set

# %%
# clean and merge datasets
master_df = cleaned_bom.merge(cleaned_rt, on='merge_key', how='inner')

# %%
# Total revenue
master_df['total_gross'] = master_df['domestic_gross'] + master_df['foreign_gross']

# %%
# Groupby Genre (Use the genre column from the ratings dataset)
genre_summary = master_df.groupby('genre_y').agg({
    'rating_y': ['mean', 'count'],
    'total_gross': ['sum', 'mean']
}).reset_index()
genre_summary.columns = ['genre', 'avg_rating', 'num_movies', 'total_gross', 'avg_gross']

# %% [markdown]
# Objective 2: How Runtime Affects Audience Ratings
# 📊 Summary Table
# |  |  |  |
# |  |  |  |
# |  |  |  |
# |  |
#
#
#
# 📈 Key Findings
# - Sweet spot: Movies between 90 and 120 minutes consistently earn the highest ratings.
# - Short films (<90 min) often lack depth or production value, leading to lower scores.
# - Long films (>120 min) may suffer from pacing issues or audience fatigue.
#
# 🧠 Strategic Recommendation
# For most genres, aim for a runtime between 90 and 120 minutes to maximize audience engagement and critical reception. Exceptions may apply for epic dramas or documentaries, but this range is your safest bet.
#
# Would you like to:
# - See a chart comparing runtime bins and ratings?
# - Move on to Insight #3: Top-performing directors and writers?
# Let’s keep building your studio strategy.
